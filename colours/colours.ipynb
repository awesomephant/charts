# %%
import pandas as pd
import numpy as np
from colorspace import sequential_hcl, diverging_hcl, qualitative_hcl, hclplot, specplot, rainbow_hcl, palette
from matplotlib import pyplot as plt

#https://retostauffer.github.io/python-colorspace/

# %%
# fig, ax = plt.subplots(figsize=(7,6))
# hclplot(sequential_hcl()(17), ax=ax)

shades = {
    "violet": [
        "#E0D3F8",
        "#CDBAF0",
        "#BBA1E8",
        "#A889E1",
        "#9570D9",
        "#8257D1",
        "#6F3DC9",
        "#5820BF",
        "#441993",
        "#301268",
        "#1D0B40"
		]
}

pal = palette(shades["violet"], "kjhdfs")

specplot(pal.colors())
hclplot(pal.colors())
plt.close()
